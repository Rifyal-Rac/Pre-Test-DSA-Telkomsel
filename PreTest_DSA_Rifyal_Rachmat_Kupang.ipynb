# %% [markdown]
# # Pretest DSA Telkomsel
# ## Telkomsel Data Science Academy
# Date: 16 October 2019<br>
# Auth: Rifyal Rachmat<br>

# %% [markdown]
# ### Explore Insight Deeply!
# in this section, I will try to dig 5 of facts with theme of __Churned Customers__

# %% [markdown]
# #### Q1. Potential states based on highest spending
# ##### What is bla bla

# %%
#Import numpy, panda, and dataset - located local E
import pandas as pd
import numpy as np
pd.DataFrame()
churn = pd.read_csv(r"E:\churn_test.csv", encoding='latin1')
churn.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %%
#column
print("kolom:",len(churn.columns))
#row
print("baris:",len(churn))
sum_day_charge= churn['total_day_charge'].sum()
sum_day_charge= churn['total_day_charge'].sum()
# Out:
# kolom: 21
# baris: 5000

# %%
churn['total_day_charge'] = churn['total_day_charge'].astype (int)
churn['total_eve_charge'] = churn['total_eve_charge'].astype (int)
churn['total_night_charge'] = churn['total_night_charge'].astype (int)
churn['total_intl_charge'] = churn['total_intl_charge'].astype (int)

# %%
top_3 = churn[['total_day_charge','state','total_eve_charge']]
a_test = 'total_day_charge'.sum()&'total_eve_charge'.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-674e14bc44b6> in <module>
#       1 top_3 = churn[['total_day_charge','state','total_eve_charge']]
# ----> 2 a_test = 'total_day_charge'.sum()&'total_eve_charge'.sum()
#
# AttributeError: 'str' object has no attribute 'sum'
